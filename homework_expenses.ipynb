# %%
expenses = [1200, 1500, 800, 600, 1000, 400, 900]

total = sum(expenses)
avg = total / len(expenses)
max_exp = max(expenses)
min_exp = min(expenses)
count_over_1000 = len([x for x in expenses if x > 1000])

total, avg, max_exp, min_exp, count_over_1000
# Out:
# (6400, 914.2857142857143, 1500, 400, 2)

# %% [markdown]
# | Показник                          | Значення |
# |----------------------------------|----------|
# | Загальна сума                    | 6400     |
# | Середнє значення                 | 914.28   |
# | Максимальна витрата              | 1500     |
# | Мінімальна витрата               | 400      |
# | Кількість днів > 1000            | 2        |
