# %%
temps = [2, 5, 4, 6, 7, 3, 1]

avg_temp = sum(temps) / len(temps)
max_temp = max(temps)
min_temp = min(temps)
diff = max_temp - min_temp

avg_temp, max_temp, min_temp, diff

# %% [markdown]
# | Показник              | Значення |
# |----------------------|----------|
# | Середнє значення     | 4.0      |
# | Максимальне значення | 7        |
# | Мінімальне значення  | 1        |
# | Різниця              | 6        |
