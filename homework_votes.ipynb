# %%
from collections import Counter

votes = ["apple", "banana", "apple", "orange", "banana", "apple", "apple", "apple", "orange"]

count = Counter(votes)

leader = count.most_common(1)[0]
top3 = count.most_common(3)

count, leader, top3

# %% [markdown]
# | Фрукт  | Кількість |
# |--------|----------|
# | apple  | 5        |
# | banana | 2        |
# | orange | 2        |

# %% [markdown]
# Топ-3:
# 1. apple — 5
# 2. banana — 2
# 3. orange — 2
